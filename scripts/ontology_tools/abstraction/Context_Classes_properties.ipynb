# %%
import os
import zipfile
import shutil
from google.colab import files

# === 1) Define paths ===
zip_path = "/content/AboxContext (2).zip"
# The folder where TTL files will reside after extraction:
extract_dir = "/content/AboxContext (2)/AboxContext"

# Folder to hold abstracted output TTLs
output_dir = "/content/Abox_Final_abstracted_family_1hop_tbox"
os.makedirs(output_dir, exist_ok=True)

# === 2) Unzip the input archive into extract_dir ===
if not os.path.exists(extract_dir):
    # Ensure parent directory exists:
    os.makedirs(os.path.dirname(extract_dir), exist_ok=True)
    with zipfile.ZipFile(zip_path, "r") as zf:
        zf.extractall(os.path.dirname(extract_dir))

# === 3) Define the replacements dictionary ===
replacements = {
    # Property mappings:
    "hasBrother":        "PropertyA",
    "hasChild":          "PropertyB",
    "hasDaughter":       "PropertyC",
    "hasSon":            "PropertyD",
    "hasPartner":        "PropertyE",
    "hasFemalePartner":  "PropertyF",
    "hasMalePartner":    "PropertyG",
    "hasRelation":       "PropertyH",
    "hasAncestor":       "PropertyI",
    "hasParent":         "PropertyJ",
    "hasFather":         "PropertyK",
    "hasMother":         "PropertyL",
    "isBloodrelationOf": "PropertyM",
    "isSiblingOf":       "PropertyN",
    "isBrotherOf":       "PropertyO",
    "isSisterOf":        "PropertyP",
    "hasSex":            "PropertyQ",
    "hasSister":         "PropertyR",
    "hasSpouse":         "PropertyS",
    "hasHusband":        "PropertyT",
    "hasWife":           "PropertyU",
    "isAncestorOf":      "PropertyV",
    "isChildOf":         "PropertyW",
    "isDaughterOf":      "PropertyX",
    "isSonOf":           "PropertyY",
    "isFatherOf":        "PropertyZ",
    "isFemalePartnerln": "Property1",
    "isHusbandOf":       "Property2",
    "isMalePartnerln":   "Property3",
    "isMotherOf":        "Property4",
    "isParentOf":        "Property5",
    "isPartnerln":       "Property6",
    "isSpouseOf":        "Property7",
    "isUncleOf":         "Property8",
    "isWifeOf":          "Property9",
    # Class mappings (prefix retained):
    "ns1:Person":       "ns1:Class1",
    "ns1:Sex":          "ns1:Class2",
    "ns1:Man":          "ns1:Class3",
    "ns1:Woman":        "ns1:Class4",
    "ns1:Ancestor":     "ns1:Class5",
    "ns1:Male":         "ns1:Class6",
    "ns1:Female":       "ns1:Class7",
    "ns1:Marriage":     "ns1:Class8",
    "ns1:DomainEntity": "ns1:Class9"
}

# === 4) Function to process a single TTL file ===
def replace_terms_in_ttl(input_file_path, output_file_path):
    with open(input_file_path, "r", encoding="utf-8") as infile:
        content = infile.read()

    for word, replacement in replacements.items():
        content = content.replace(word, replacement)

    with open(output_file_path, "w", encoding="utf-8") as outfile:
        outfile.write(content)

# === 5) Walk through all .ttl files under extract_dir ===
for root, _, files_in_dir in os.walk(extract_dir):
    for fname in files_in_dir:
        if fname.lower().endswith(".ttl"):
            full_input_path = os.path.join(root, fname)

            # Determine a parallel output path under output_dir:
            # e.g., if input is /content/.../family_1hop_no_tbox/PersonA.ttl
            # then output will be /content/abstracted_family_1hop_no_tbox/PersonA.ttl
            rel_path = os.path.relpath(full_input_path, extract_dir)
            full_output_path = os.path.join(output_dir, rel_path)

            # Ensure the output subdirectory exists
            os.makedirs(os.path.dirname(full_output_path), exist_ok=True)

            # Perform replacement
            replace_terms_in_ttl(full_input_path, full_output_path)
            print(f"Processed: {rel_path}")

# === 6) Zip the entire output_dir so it can be downloaded ===
zip_output_path = "/content/Abox_Final_abstracted_family_1hop_tbox.zip"
if os.path.exists(zip_output_path):
    os.remove(zip_output_path)

shutil.make_archive(base_name="/content/Abox_Final_abstracted_family_1hop_tbox",
                    format="zip",
                    root_dir=output_dir)

# === 7) Download the zipped folder ===
files.download(zip_output_path)
# Out:
# Processed: Thing_john_hollinsworth_1768.ttl
# Processed: Thing_richard_pickard_1807.ttl
# Processed: Thing_m182.ttl
# Processed: Thing_james_jacobs_1806.ttl
# Processed: Thing_edmund_bright_1813.ttl
# Processed: Thing_christopher_archer_1849.ttl
# Processed: Thing_james_stafford_1803.ttl
# Processed: Thing_stephen_templar_1960.ttl
# Processed: Thing_eileen_mary_rever_1929.ttl
# Processed: Thing_james_jessop_1836.ttl
# Processed: Thing_m177.ttl
# Processed: Thing_sarah_ingelby_1821.ttl
# Processed: Thing_george_stafford_1807.ttl
# Processed: Thing_m157.ttl
# Processed: Thing_james_alexander_bright_1921.ttl
# Processed: Thing_george_baker_lockey_1812.ttl
# Processed: Thing_harriet_ann_whitfield_1850.ttl
# Processed: Thing_caroline_bright_1822.ttl
# Processed: Thing_mary_eliza_jessop_1863.ttl
# Processed: Thing_lois_green_1871.ttl
# Processed: Thing_m126.ttl
# Processed: Thing_alfred_steward_1846.ttl
# Processed: Thing_mary_hollingsworth_1801.ttl
# Processed: Thing_william_bright_1970.ttl
# Processed: Thing_sarah_jane_whitfield_1829.ttl
# Processed: Thing_caroline_cox.ttl
# Processed: Thing_mabel_rever_1897.ttl
# Processed: Thing_m162.ttl
# Processed: Thing_john_green_1802.ttl
# Processed: Thing_m141.ttl
# Processed: Thing_susannah_tacey_1834.ttl
# Processed: Thing_james_bright_1964.ttl
# Processed: Thing_eleanor_harsley_1808.ttl
# Processed: Thing_ethel_harvey_1888.ttl
# Processed: Thing_elizabeth_harsley_1803.ttl
# Processed: Thing_george_jacobs_1852.ttl
# Processed: Thing_charlotte_cotton_1840.ttl
# Processed: Thing_amanda_usher_1968.ttl
# Processed: Thing_martha_cotton_1832.ttl
# Processed: Thing_eleanor_frances_green_1863.ttl
# Processed: Thing_edward_young_1821.ttl
# Processed: Thing_humphrey_archer_1726.ttl
# Processed: Thing_mary_tacey_1811.ttl
# Processed: Thing_caroline_lavinia_tubb_1840.ttl
# Processed: Thing_ann_norton_1799.ttl
# Processed: Thing_mark_steward_1811.ttl
# Processed: Thing_elizabeth_clamper_1760.ttl
# Processed: Thing_william_george_bright_1901.ttl
# Processed: Thing_edward_tubb_1827.ttl
# Processed: Thing_john_lockey_1789.ttl
# Processed: Thing_anne_lockey_1829.ttl
# Processed: Thing_annie_whitfield.ttl
# Processed: Thing_alan_john_dowse_1936.ttl
# Processed: Thing_frank_terliven_1877.ttl
# Processed: Thing_jean_margaret_archer_1934.ttl
# Processed: Thing_thomas_tacey_1806.ttl
# Processed: Thing_james_bright_1839.ttl
# Processed: Thing_charles_jessop_1831.ttl
# Processed: Thing_james_keith_archer_1946.ttl
# Processed: Thing_m134.ttl
# Processed: Thing_m103.ttl
# Processed: Thing_john_steward_1802.ttl
# Processed: Thing_james_hewett_1815.ttl
# Processed: Thing_herbert_vincent_jessop_1871.ttl
# Processed: Thing_william_lock.ttl
# Processed: Thing_iris_ellen_archer_1906.ttl
# Processed: Thing_mary_bainton_1780.ttl
# Processed: Thing_james_frank_hayden_bright_1891.ttl
# Processed: Thing_john_tubb_1816.ttl
# Processed: Thing_dorothy_archer_1845.ttl
# Processed: Thing_sarah_jane_whitfield_1818.ttl
# Processed: Thing_leonard_john_bright_1890.ttl
# Processed: Thing_emma_templar_1991.ttl
# Processed: Thing_m138.ttl
# Processed: Thing_james_alexander_archer_1882.ttl
# Processed: Thing_john_tacey_steward_1873.ttl
# Processed: Thing_daniel_grigg_hewett_1813.ttl
# Processed: Thing_hannah_hutchinson_1804.ttl
# Processed: Thing_john_henry_harvey.ttl
# Processed: Thing_george_steward_1835.ttl
# Processed: Thing_beatrice_rever_1901.ttl
# Processed: Thing_daisy_harriet_heath_1889.ttl
# Processed: Thing_mary_tacey_1808.ttl
# Processed: Thing_ellen_steward_1797.ttl
# Processed: Thing_jane_bright_1820.ttl
# Processed: Thing_martha_cotton_1806.ttl
# Processed: Thing_thomas_burton_1765.ttl
# Processed: Thing_dereck_heath_1929.ttl
# Processed: Thing_m147.ttl
# Processed: Thing_ann_james.ttl
# Processed: Thing_eliza_bright_1842.ttl
# Processed: Thing_george_whitfield_1865.ttl
# Processed: Thing_elizabeth_blanchard_1807.ttl
# Processed: Thing_jane_burton_1823.ttl
# Processed: Thing_john_cotton_1778.ttl
# Processed: Thing_betsy_ann_steward_1865.ttl
# Processed: Thing_sarah_jacobs_1834.ttl
# Processed: Thing_eliza_bright_1825.ttl
# Processed: Thing_david_brown.ttl
# Processed: Thing_m169.ttl
# Processed: Thing_sarah_lockey_1810.ttl
# Processed: Thing_catherine_steward_1863.ttl
# Processed: Thing_m117.ttl
# Processed: Thing_elizabeth_ann_lockey_1846.ttl
# Processed: Thing_william_lock_jacobs_1861.ttl
# Processed: Thing_m127.ttl
# Processed: Thing_james_tubb_1809.ttl
# Processed: Thing_m155.ttl
# Processed: Thing_elizabeth_frances_jessop_1869.ttl
# Processed: Thing_m166.ttl
# Processed: Thing_james_hollinsworth_1804.ttl
# Processed: Thing_henry_waterloo_lockey_1820.ttl
# Processed: Thing_william_tubb_1786.ttl
# Processed: Thing_charles_jacobs_1842.ttl
# Processed: Thing_joyce_archer_1921.ttl
# Processed: Thing_george_steward_1856.ttl
# Processed: Thing_william_rever_1870.ttl
# Processed: Thing_ann_hollinsworth_1808.ttl
# Processed: Thing_edward_cotton_1850.ttl
# Processed: Thing_elizabeth_gray_1810.ttl
# Processed: Thing_vincent_cotton_1808.ttl
# Processed: Thing_peter_william_bright_1941.ttl
# Processed: Thing_james_bright_1787.ttl
# Processed: Thing_sarah_jewell_1790.ttl
# Processed: Thing_rose_evlyn_rever_1906.ttl
# Processed: Thing_mary_green_1803.ttl
# Processed: Thing_ian_bright_1959.ttl
# Processed: Thing_mary_ann_cotton_1847.ttl
# Processed: Thing_eden_georgina_gardner_thompson_1810.ttl
# Processed: Thing_mary_ann_green_1846.ttl
# Processed: Thing_james_bright_1761.ttl
# Processed: Thing_charlotte_bright_1928.ttl
# Processed: Thing_benjamin_anthony_heath_2005.ttl
# Processed: Thing_ann_jessop_1833.ttl
# Processed: Thing_sarah_bright_1817.ttl
# Processed: Thing_holly_bright_1983.ttl
# Processed: Thing_harry_whitfield_1854.ttl
# Processed: Thing_m165.ttl
# Processed: Thing_alec_john_archer_1927.ttl
# Processed: Thing_edward_jessop_1802.ttl
# Processed: Thing_ethel_archer_1912.ttl
# Processed: Thing_elma_ellen_story_1893.ttl
# Processed: Thing_william_green_1813.ttl
# Processed: Thing_matthew_tacey_1837.ttl
# Processed: Thing_elma_harvey_1903.ttl
# Processed: Thing_avril_bright_1990.ttl
# Processed: Thing_m160.ttl
# Processed: Thing_henry_young_1831.ttl
# Processed: Thing_mary_archer_1885.ttl
# Processed: Thing_john_heath.ttl
# Processed: Thing_ann_green_1806.ttl
# Processed: Thing_florelle_nenuphar_heath_1880.ttl
# Processed: Thing_clare_bright_1966.ttl
# Processed: Thing_james_whitfield_1792.ttl
# Processed: Thing_henry_edmund_bright_1887.ttl
# Processed: Thing_john_archer_1835.ttl
# Processed: Thing_tamar_green_1810.ttl
# Processed: Thing_katherine_emma_terliven_1871.ttl
# Processed: Thing_george_ingelby_1814.ttl
# Processed: Thing_james_dickens_1774.ttl
# Processed: Thing_ralph_pickard_1775.ttl
# Processed: Thing_henrietta_sarah_green_1873.ttl
# Processed: Thing_john_harsley_1791.ttl
# Processed: Thing_george_pickard_1847.ttl
# Processed: Thing_sarah_pickard_1839.ttl
# Processed: Thing_elizabeth_pickard_1805.ttl
# Processed: Thing_finlay_alex_clamper_2002.ttl
# Processed: Thing_charlotte_hewett_1863.ttl
# Processed: Thing_norman_james_archer_1909.ttl
# Processed: Thing_robert_hewett_1807.ttl
# Processed: Thing_peter_templar_1962.ttl
# Processed: Thing_janet_bright_1964.ttl
# Processed: Thing_eric_cleife_1951.ttl
# Processed: Thing_m105.ttl
# Processed: Thing_edward_jessop_1867.ttl
# Processed: Thing_frederick_herbert_bright_1889.ttl
# Processed: Thing_james_bright_1809.ttl
# Processed: Thing_arthur_steward_1861.ttl
# Processed: Thing_celia_pinchbeck_1949.ttl
# Processed: Thing_martin_dowse_1944.ttl
# Processed: Thing_jane_jacobs_1836.ttl
# Processed: Thing_harry_bright_hostler.ttl
# Processed: Thing_hannah_green_1839.ttl
# Processed: Thing_ann_jacobs_1832.ttl
# Processed: Thing_john_william_tacey_1841.ttl
# Processed: Thing_frances_elizabeth_ingelby_1816.ttl
# Processed: Thing_amelia_jessop_1837.ttl
# Processed: Thing_m135.ttl
# Processed: Thing_sarah_rever_1850.ttl
# Processed: Thing_thomas_taisy.ttl
# Processed: Thing_charles_pickard_1854.ttl
# Processed: Thing_m164.ttl
# Processed: Thing_john_lockey_1840.ttl
# Processed: Thing_lucy_jacobs_1844.ttl
# Processed: Thing_christian_bright_1985.ttl
# Processed: Thing_harsley_steward_1839.ttl
# Processed: Thing_henry_edmund_bright_1862.ttl
# Processed: Thing_ellen_jessop_1844.ttl
# Processed: Thing_catherine_thompson.ttl
# Processed: Thing_margaret_grace_rever_1934.ttl
# Processed: Thing_m118.ttl
# Processed: Thing_charles_herbert_rever_1895.ttl
# Processed: Thing_henry_tubb_1825.ttl
# Processed: Thing_gwendoline_heath_1878.ttl
# Processed: Thing_mary_dickens_1802.ttl
# Processed: Thing_james_whitfield_1821.ttl
# Processed: Thing_henry_jacobs_1849.ttl
# Processed: Thing_bethia_burton_1821.ttl
# Processed: Thing_charlotte_caroline_jane_bright_1894.ttl
# Processed: Thing_elizabeth_quincey_green_1886.ttl
# Processed: Thing_arthur_tuton.ttl
# Processed: Thing_david_bright_1934.ttl
# Processed: Thing_samuel_tubb_1811.ttl
# Processed: Thing_ada_steward_1871.ttl
# Processed: Thing_susanna_walkerly_1777.ttl
# Processed: Thing_james_stafford_1779.ttl
# Processed: Thing_m149.ttl
# Processed: Thing_clarence_john_heath_1896.ttl
# Processed: Thing_fred_steward_1869.ttl
# Processed: Thing_harriet_whitefield_1861.ttl
# Processed: Thing_laura_templar_1994.ttl
# Processed: Thing_rebecca_harsley_1793.ttl
# Processed: Thing_ellen_steward_1844.ttl
# Processed: Thing_m106.ttl
# Processed: Thing_elizabeth_cotton_1838.ttl
# Processed: Thing_m180.ttl
# Processed: Thing_m179.ttl
# Processed: Thing_henry_green_1836.ttl
# Processed: Thing_john_hewson_stafford_1811.ttl
# Processed: Thing_charlotte_ann_jessop_1865.ttl
# Processed: Thing_john_archer_1804.ttl
# Processed: Thing_mary_lockey_1818.ttl
# Processed: Thing_fanny_jacobs_1840.ttl
# Processed: Thing_frank_reginald_green_1883.ttl
# Processed: Thing_susanna_cotton_1836.ttl
# Processed: Thing_henry_edmond_peter_bright_1926.ttl
# Processed: Thing_elizabeth_rivers_1787.ttl
# Processed: Thing_james_steward_1798.ttl
# Processed: Thing_m132.ttl
# Processed: Thing_sarah_dickens_1801.ttl
# Processed: Thing_harriet_ann_young_1825.ttl
# Processed: Thing_george_green_1834.ttl
# Processed: Thing_sarah_jane_tubb_1812.ttl
# Processed: Thing_diana_pool.ttl

# %%
# === 6) Zip the entire output_dir so it can be downloaded ===
zip_output_path = "/content/Final_abstracted_family_1hop_tbox.zip"
if os.path.exists(zip_output_path):
    os.remove(zip_output_path)

shutil.make_archive(base_name="/content/Final_abstracted_family_1hop_tbox",
                    format="zip",
                    root_dir=output_dir)

# === 7) Download the zipped folder ===
files.download(zip_output_path)
